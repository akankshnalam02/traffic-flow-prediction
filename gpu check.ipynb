# %%
import os
print(os.getcwd())
# Out:
# C:\Users\akanksh_02\Downloads\trf\STG4Traffic\TrafficSpeed\GWNET

# %%
# !python ../lib/generate_data.py --dataset PEMSBAY --input_dir ../../PEMS-BAY --output_dir data/PEMSBAY
# Out:
# usage: generate_data.py [-h] [--window WINDOW] [--horizon HORIZON]
#                         [--train_rate TRAIN_RATE] [--val_rate VAL_RATE]
#                         [--dataset DATASET]
# generate_data.py: error: unrecognized arguments: --input_dir ../../PEMS-BAY --output_dir data/PEMSBAY

# %%
# !mkdir TrafficSpeed/data/PEMSBAY
# !move PEMS-BAY\pems-bay.h5 TrafficSpeed\data\PEMSBAY\
# !move PEMS-BAY\adj_mx_bay.pkl TrafficSpeed\data\PEMSBAY\
# Out:
# The syntax of the command is incorrect.
# The system cannot find the file specified.

# %%
# -------------------------------------------------------------
# Device
# -------------------------------------------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)


# -------------------------------------------------------------
# GPU speed boost
# -------------------------------------------------------------
torch.backends.cudnn.benchmark = True
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[1], line 4
#       1 # -------------------------------------------------------------
#       2 # Device
#       3 # -------------------------------------------------------------
# ----> 4 device = "cuda" if torch.cuda.is_available() else "cpu"
#       5 print("Device:", device)
#       8 # -------------------------------------------------------------
#       9 # GPU speed boost
#      10 # -------------------------------------------------------------
#
# NameError: name 'torch' is not defined

# %%
# =============================================================
# 0️⃣ IMPORTS + DEVICE + STABILITY SETTINGS
# =============================================================
import numpy as np
import pandas as pd
import pickle
import torch
import torch.nn as nn
import torch.nn.functional as F
from torch.utils.data import Dataset, DataLoader
import random
import math


# -------------------------------------------------------------
# Reproducibility
# -------------------------------------------------------------
SEED = 42

random.seed(SEED)
np.random.seed(SEED)
torch.manual_seed(SEED)
torch.cuda.manual_seed_all(SEED)


# -------------------------------------------------------------
# Device
# -------------------------------------------------------------
device = "cuda" if torch.cuda.is_available() else "cpu"
print("Device:", device)


# -------------------------------------------------------------
# GPU speed boost
# -------------------------------------------------------------
torch.backends.cudnn.benchmark = True
# Out:
# Device: cuda

# %%
import torch
print(torch.cuda.is_available())
print(torch.cuda.get_device_name(0) if torch.cuda.is_available() else "No GPU")

# Check GPU memory
print(torch.cuda.memory_allocated())
print(torch.cuda.memory_reserved())
# Out:
# True
# NVIDIA GeForce RTX 3050 Laptop GPU
# 0
# 0

# %%
# simple GPU test
x = torch.randn(5000, 5000).to("cuda")
y = x @ x

print("Allocated:", torch.cuda.memory_allocated() / 1e6, "MB")
print("Reserved :", torch.cuda.memory_reserved() / 1e6, "MB")
# Out:
# Allocated: 209.846272 MB
# Reserved : 222.298112 MB

# %%
if epoch == 0 and batch_idx == 0:
    print("Model device:", next(model.parameters()).device)
    print("Batch device:", x.device)
    print("GPU Allocated (MB):", torch.cuda.memory_allocated() / 1e6)
# Out:
# ---------------------------------------------------------------------------
# NameError                                 Traceback (most recent call last)
# Cell In[9], line 1
# ----> 1 if epoch == 0 and batch_idx == 0:
#       2     print("Model device:", next(model.parameters()).device)
#       3     print("Batch device:", x.device)
#
# NameError: name 'epoch' is not defined

# %%
import torch

print("PyTorch version:", torch.__version__)
print("CUDA available:", torch.cuda.is_available())
print("CUDA version:", torch.version.cuda)
print("Device count:", torch.cuda.device_count())

if torch.cuda.is_available():
    print("GPU name:", torch.cuda.get_device_name(0))
    print("Current device:", torch.cuda.current_device())
# Out:
# PyTorch version: 2.4.1+cu121
# CUDA available: True
# CUDA version: 12.1
# Device count: 1
# GPU name: NVIDIA GeForce RTX 3050 Laptop GPU
# Current device: 0

# %%
import os
os.environ["CUDA_VISIBLE_DEVICES"] = "0"

# %%
import torch
assert torch.cuda.is_available()
torch.cuda.set_device(0)
